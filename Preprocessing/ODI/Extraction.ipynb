# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath(os.getcwd())))

# %%
BASE_DIR
# Out:
# 'd:\\Projects\\Cricket-Score-Predictor'

# %%
data = os.path.join(BASE_DIR,'Dataset','odis')

# %%
data
# Out:
# 'd:\\Projects\\Cricket-Score-Predictor\\Dataset\\odis'

# %%
files = []
for file in os.listdir(data):
    files.append(os.path.join(data,file))

# %%
files[0:5]
# Out:
# ['d:\\Projects\\Cricket-Score-Predictor\\Dataset\\odis\\1000887.yaml',
#  'd:\\Projects\\Cricket-Score-Predictor\\Dataset\\odis\\1000889.yaml',
#  'd:\\Projects\\Cricket-Score-Predictor\\Dataset\\odis\\1000891.yaml',
#  'd:\\Projects\\Cricket-Score-Predictor\\Dataset\\odis\\1000893.yaml',
#  'd:\\Projects\\Cricket-Score-Predictor\\Dataset\\odis\\1000895.yaml']

# %%
df = pd.DataFrame()
counter = 1
for file in tqdm(files):
    with open(file,'r') as f:
        df1 = pd.json_normalize(safe_load(f))
        df1['match_id'] = counter
        df = pd.concat([df, df1], ignore_index=True)
        counter += 1
df
# Out:
#   0%|          | 0/2913 [00:00<?, ?it/s]
# 100%|█████████▉| 2912/2913 [18:54<00:00,  2.57it/s]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[8], line 5
#       3 for file in tqdm(files):
#       4     with open(file,'r') as f:
# ----> 5         df1 = pd.json_normalize(safe_load(f))
#       6         df1['match_id'] = counter
#       7         df = pd.concat([df, df1], ignore_index=True)
#
# File d:\Projects\Cricket-Score-Predictor\.venv\Lib\site-packages\pandas\io\json\_normalize.py:445, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     443     data = list(data)
#     444 else:
# --> 445     raise NotImplementedError
#     447 # check to see if a simple recursive function is possible to
#     448 # improve performance (see #15621) but only for cases such
#     449 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     450 if (
#     451     record_path is None
#     452     and meta is None
#    (...)    455     and max_level is None
#     456 ):
#
# NotImplementedError:

# %%
backup = df.copy()
df
# Out:
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 1     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 2     [{'1st innings': {'team': 'Pakistan', 'deliver...               0.91
# 3     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 4     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# ...                                                 ...                ...
# 2907  [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
# 2908  [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
# 2909  [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
# 2910  [{'1st innings': {'team': 'Scotland', 'deliver...               0.91
# 2911  [{'1st innings': {'team': 'United Arab Emirate...               0.91
#
#      meta.created  meta.revision  info.balls_per_over  info.city  \
# 0      2017-01-14              2                    6   Brisbane
# 1      2017-01-18              1                    6        NaN
# 2      2017-01-21              1                    6      Perth
# 3      2017-01-22              1                    6        NaN
# 4      2017-01-28              1                    6        NaN
# ...           ...            ...                  ...        ...
# 2907   2016-08-31              1                    6        NaN
# 2908   2016-09-02              2                    6        NaN
# 2909   2016-09-12              2                    6        NaN
# 2910   2016-08-20              1                    6  Edinburgh
# 2911   2016-08-20              1                    6  Edinburgh
#
#         info.dates info.gender info.match_type  info.outcome.by.runs  ...  \
# 0     [2017-01-13]        male             ODI                  92.0  ...
# 1     [2017-01-15]        male             ODI                   NaN  ...
# 2     [2017-01-19]        male             ODI                   NaN  ...
# 3     [2017-01-22]        male             ODI                  86.0  ...
# 4     [2017-01-26]        male             ODI                  57.0  ...
# ...            ...         ...             ...                   ...  ...
# 2907  [2016-08-28]        male             ODI                   NaN  ...
# 2908  [2016-08-31]        male             ODI                   NaN  ...
# 2909  [2016-09-04]        male             ODI                   NaN  ...
# 2910  [2016-08-14]        male             ODI                  98.0  ...
# 2911  [2016-08-16]        male             ODI                   NaN  ...
#
#      info.registry.people.Waleed Yaqub  info.registry.people.RN Hendricks  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# ...                                ...                                ...
# 2907                               NaN                                NaN
# 2908                               NaN                                NaN
# 2909                               NaN                                NaN
# 2910                               NaN                                NaN
# 2911                               NaN                                NaN
#
#      info.registry.people.SP Terry info.registry.people.DJ Worrall  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
# ...                            ...                             ...
# 2907                           NaN                             NaN
# 2908                           NaN                             NaN
# 2909                           NaN                             NaN
# 2910                           NaN                             NaN
# 2911                           NaN                             NaN
#
#      info.registry.people.CP Tremain info.registry.people.JM Mennie  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 2907                             NaN                            NaN
# 2908                             NaN                            NaN
# 2909                             NaN                            NaN
# 2910                             NaN                            NaN
# 2911                             NaN                            NaN
#
#      info.registry.people.DS Weerakkody info.registry.people.IG Warne  \
# 0                                   NaN                           NaN
# 1                                   NaN                           NaN
# 2                                   NaN                           NaN
# 3                                   NaN                           NaN
# 4                                   NaN                           NaN
# ...                                 ...                           ...
# 2907                                NaN                           NaN
# 2908                                NaN                           NaN
# 2909                                NaN                           NaN
# 2910                                NaN                           NaN
# 2911                                NaN                           NaN
#
#      info.registry.people.CC Dalton info.registry.people.S Wijesundera
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
# ...                             ...                                ...
# 2907                            NaN                                NaN
# 2908                            NaN                                NaN
# 2909                            NaN                                NaN
# 2910                            NaN                                NaN
# 2911                            NaN                                NaN
#
# [2912 rows x 3108 columns]

# %%
df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.supersubs.South Africa',
    'info.supersubs.New Zealand',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
],inplace=True)

# %%
df = df[df['info.gender'] == 'male']
df.drop(columns=['info.gender'],inplace=True)
df
# Out:
# C:\Users\vishw\AppData\Local\Temp\ipykernel_8500\3051552985.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['info.gender'],inplace=True)
#                                                 innings  info.balls_per_over  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...                    6
# 1     [{'1st innings': {'team': 'Australia', 'delive...                    6
# 2     [{'1st innings': {'team': 'Pakistan', 'deliver...                    6
# 3     [{'1st innings': {'team': 'Australia', 'delive...                    6
# 4     [{'1st innings': {'team': 'Australia', 'delive...                    6
# ...                                                 ...                  ...
# 2907  [{'1st innings': {'team': 'Sri Lanka', 'delive...                    6
# 2908  [{'1st innings': {'team': 'Sri Lanka', 'delive...                    6
# 2909  [{'1st innings': {'team': 'Sri Lanka', 'delive...                    6
# 2910  [{'1st innings': {'team': 'Scotland', 'deliver...                    6
# 2911  [{'1st innings': {'team': 'United Arab Emirate...                    6
#
#       info.city    info.dates info.match_type info.outcome.winner  info.overs  \
# 0      Brisbane  [2017-01-13]             ODI           Australia          50
# 1           NaN  [2017-01-15]             ODI            Pakistan          50
# 2         Perth  [2017-01-19]             ODI           Australia          50
# 3           NaN  [2017-01-22]             ODI           Australia          50
# 4           NaN  [2017-01-26]             ODI           Australia          50
# ...         ...           ...             ...                 ...         ...
# 2907        NaN  [2016-08-28]             ODI           Australia          50
# 2908        NaN  [2016-08-31]             ODI           Australia          50
# 2909        NaN  [2016-09-04]             ODI           Australia          50
# 2910  Edinburgh  [2016-08-14]             ODI            Scotland          50
# 2911  Edinburgh  [2016-08-16]             ODI            Scotland          50
#
#      info.player_of_match                             info.players.Australia  \
# 0               [MS Wade]  [DA Warner, TM Head, SPD Smith, CA Lynn, MR Ma...
# 1       [Mohammad Hafeez]  [UT Khawaja, DA Warner, SPD Smith, MR Marsh, T...
# 2             [SPD Smith]  [DA Warner, UT Khawaja, SPD Smith, PSP Handsco...
# 3             [DA Warner]  [UT Khawaja, DA Warner, SPD Smith, TM Head, GJ...
# 4             [DA Warner]  [DA Warner, TM Head, SPD Smith, GJ Maxwell, MS...
# ...                   ...                                                ...
# 2907          [GJ Bailey]  [DA Warner, AJ Finch, SE Marsh, GJ Bailey, TM ...
# 2908        [JW Hastings]  [DA Warner, AJ Finch, UT Khawaja, GJ Bailey, T...
# 2909          [DA Warner]  [DA Warner, MS Wade, UT Khawaja, GJ Bailey, TM...
# 2910                  NaN                                                NaN
# 2911                  NaN                                                NaN
#
#                                   info.players.Pakistan  ...  \
# 0     [Azhar Ali, Sharjeel Khan, Mohammad Hafeez, Ba...  ...
# 1     [Mohammad Hafeez, Sharjeel Khan, Babar Azam, A...  ...
# 2     [Mohammad Hafeez, Sharjeel Khan, Babar Azam, A...  ...
# 3     [Azhar Ali, Sharjeel Khan, Babar Azam, Mohamma...  ...
# 4     [Azhar Ali, Sharjeel Khan, Babar Azam, Mohamma...  ...
# ...                                                 ...  ...
# 2907                                                NaN  ...
# 2908                                                NaN  ...
# 2909                                                NaN  ...
# 2910                                                NaN  ...
# 2911                                                NaN  ...
#
#      info.registry.people.Waleed Yaqub info.registry.people.RN Hendricks  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
# ...                                ...                               ...
# 2907                               NaN                               NaN
# 2908                               NaN                               NaN
# 2909                               NaN                               NaN
# 2910                               NaN                               NaN
# 2911                               NaN                               NaN
#
#      info.registry.people.SP Terry info.registry.people.DJ Worrall  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
# ...                            ...                             ...
# 2907                           NaN                             NaN
# 2908                           NaN                             NaN
# 2909                           NaN                             NaN
# 2910                           NaN                             NaN
# 2911                           NaN                             NaN
#
#      info.registry.people.CP Tremain info.registry.people.JM Mennie  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 2907                             NaN                            NaN
# 2908                             NaN                            NaN
# 2909                             NaN                            NaN
# 2910                             NaN                            NaN
# 2911                             NaN                            NaN
#
#      info.registry.people.DS Weerakkody info.registry.people.IG Warne  \
# 0                                   NaN                           NaN
# 1                                   NaN                           NaN
# 2                                   NaN                           NaN
# 3                                   NaN                           NaN
# 4                                   NaN                           NaN
# ...                                 ...                           ...
# 2907                                NaN                           NaN
# 2908                                NaN                           NaN
# 2909                                NaN                           NaN
# 2910                                NaN                           NaN
# 2911                                NaN                           NaN
#
#      info.registry.people.CC Dalton info.registry.people.S Wijesundera
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
# ...                             ...                                ...
# 2907                            NaN                                NaN
# 2908                            NaN                                NaN
# 2909                            NaN                                NaN
# 2910                            NaN                                NaN
# 2911                            NaN                                NaN
#
# [2425 rows x 3095 columns]

# %%
df['info.match_type'].value_counts()
# Out:
# info.match_type
# ODI    2425
# Name: count, dtype: int64

# %%
df['info.overs'].value_counts()
# Out:
# info.overs
# 50    2425
# Name: count, dtype: int64

# %%
df = df[df['info.overs'] == 50]
df.drop(columns=['info.overs','info.match_type'],inplace=True)

# %%
import pickle
pickle.dump(df,open('dataset_level1.pkl','wb'))

# %%
df.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.2: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.3: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.4: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.5: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'extras': {'wides': 1},
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {0.6: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.7: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.1: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.2: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {1.3: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.4: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.5: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.6: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.1: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {2.2: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.3: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {2.4: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {2.5: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.6: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {3.1: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {3.2: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {3.3: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.4: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {3.5: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.6: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {4.1: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {4.2: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {4.3: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'kind': 'bowled', 'player_out': 'DA Warner'}}},
#  {4.4: {'batsman': 'SPD Smith',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Mohammad Rizwan'],
#     'kind': 'caught',
#     'player_out': 'SPD Smith'}}},
#  {4.5: {'batsman': 'CA Lynn',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {4.6: {'batsman': 'CA Lynn',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {5.1: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {5.2: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {5.3: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {5.4: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 4, 'extras': 0, 'non_boundary': 1, 'total': 4}}},
#  {5.5: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'extras': {'wides': 1},
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {5.6: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {5.7: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.1: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.2: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.3: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.4: {'batsman': 'CA Lynn',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {6.5: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.6: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {7.1: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {7.2: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.3: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {7.4: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {7.5: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 4, 'extras': 0, 'non_boundary': 1, 'total': 4}}},
#  {7.6: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.1: {'batsman': 'CA Lynn',
#    'bowler': 'Wahab Riaz',
#    'extras': {'wides': 1},
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {8.2: {'batsman': 'CA Lynn',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {8.3: {'batsman': 'TM Head',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {8.4: {'batsman': 'TM Head',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {8.5: {'batsman': 'TM Head',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {8.6: {'batsman': 'TM Head',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.7: {'batsman': 'TM Head',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {9.1: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {9.2: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Mohammad Rizwan'],
#     'kind': 'caught',
#     'player_out': 'CA Lynn'}}},
#  {9.3: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {9.4: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {9.5: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {9.6: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {10.1: {'batsman': 'TM Head',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {10.2: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.3: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.4: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.5: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.6: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {11.1: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {11.2: {'batsman': 'MR Marsh',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {11.3: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {11.4: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {11.5: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {11.6: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.1: {'batsman': 'TM Head',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {12.2: {'batsman': 'TM Head',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {12.3: {'batsman': 'TM Head',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.4: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {12.5: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.6: {'batsman': 'TM Head',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Mohammad Rizwan'],
#     'kind': 'caught',
#     'player_out': 'TM Head'}}},
#  {13.1: {'batsman': 'MR Marsh',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.2: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {13.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {13.4: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {13.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {13.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {14.1: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {14.2: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {14.3: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {14.4: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.6: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.2: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {15.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.4: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.5: {'batsman': 'MR Marsh',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.6: {'batsman': 'MR Marsh',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {16.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.2: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Mohammad Rizwan'],
#     'kind': 'caught',
#     'player_out': 'MR Marsh'}}},
#  {16.3: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.4: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.5: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {17.1: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.2: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.3: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'extras': {'wides': 1},
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {17.4: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {17.5: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {17.7: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.2: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {18.3: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {18.4: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {18.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {19.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {19.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {19.5: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {20.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {20.2: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {20.3: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {20.4: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {20.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {20.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {21.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {21.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {21.3: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {21.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {21.5: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {21.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {22.1: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {22.2: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {22.3: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {22.4: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {22.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {22.6: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {23.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {23.2: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {23.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {23.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {23.5: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {23.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {24.1: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {24.2: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {24.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {24.4: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {24.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {24.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {25.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {25.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {25.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {25.4: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {25.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {25.6: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {26.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {26.2: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {26.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {26.4: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {26.5: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {26.6: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {27.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {27.2: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {27.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {27.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {27.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {27.6: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {28.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {28.2: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {28.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {28.4: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {28.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {28.6: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {29.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {29.2: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {29.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {29.4: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'extras': {'wides': 1},
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {29.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {29.6: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {29.7: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {30.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {30.2: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'extras': {'wides': 1},
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {30.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {30.4: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {30.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {30.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {30.7: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Mohammad Hafeez'],
#     'kind': 'caught',
#     'player_out': 'GJ Maxwell'}}},
#  {31.1: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'JP Faulkner',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {31.2: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'JP Faulkner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {31.3: {'batsman': 'JP Faulkner',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {31.4: {'batsman': 'JP Faulkner',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {31.5: {'batsman': 'JP Faulkner',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {31.6: {'batsman': 'JP Faulkner',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {32.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'JP Faulkner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {32.2: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Hafeez',
#    'extras': {'wides': 1},
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {32.3: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {32.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'JP Faulkner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {32.5: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {32.6: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {32.7: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {33.1: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {33.2: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {33.3: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'JP Faulkner',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {33.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'JP Faulkner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {33.5: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {33.6: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Mohammad Hafeez'],
#     'kind': 'caught',
#     'player_out': 'JP Faulkner'}}},
#  {34.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {34.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {34.3: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {34.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {34.5: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {34.6: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {35.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {35.2: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {35.3: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {35.4: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {35.5: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {35.6: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {36.1: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {36.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {36.3: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {36.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {36.5: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {36.6: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {37.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {37.2: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {37.3: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {37.4: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {37.5: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {37.6: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {38.1: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {38.2: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'extras': {'legbyes': 1},
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {38.3: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {38.4: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {38.5: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {38.6: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {39.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {39.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {39.3: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {39.4: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {39.5: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {39.6: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {40.1: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {40.2: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {40.3: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {40.4: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {40.5: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {40.6: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {41.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {41.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {41.3: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {41.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {41.5: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {41.6: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {42.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {42.2: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {42.3: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {42.4: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {42.5: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Amir',
#    'extras': {'wides': 1},
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {42.6: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Umar Akmal', 'Mohammad Amir'],
#     'kind': 'run out',
#     'player_out': 'PJ Cummins'}}},
#  {42.7: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {43.1: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'extras': {'noballs': 1},
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {43.2: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {43.3: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {43.4: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {43.5: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {43.6: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {43.7: {'batsman': 'MA Starc',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {44.1: {'batsman': 'MA Starc',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {44.2: {'batsman': 'MA Starc',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {44.3: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {44.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {44.5: {'batsman': 'MA Starc',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {44.6: {'batsman': 'MA Starc',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {45.1: {'batsman': 'MA Starc',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {45.2: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {45.3: {'batsman': 'MA Starc',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {45.4: {'batsman': 'MA Starc',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'kind': 'bowled', 'player_out': 'MA Starc'}}},
#  {45.5: {'batsman': 'B Stanlake',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {45.6: {'batsman': 'B Stanlake',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {46.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {46.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {46.3: {'batsman': 'B Stanlake',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {46.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {46.5: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {46.6: {'batsman': 'B Stanlake',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {47.1: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {47.2: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {47.3: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {47.4: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {47.5: {'batsman': 'B Stanlake',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {47.6: {'batsman': 'B Stanlake',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {48.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {48.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {48.3: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'extras': {'wides': 1},
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {48.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {48.5: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {48.6: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {48.7: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {49.1: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {49.2: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {49.3: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {49.4: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {49.5: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {49.6: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}]

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in df.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = pd.concat([delivery_df, loop_df], ignore_index=True)

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#         match_id                             teams          batting_team  \
# 0              2             [Australia, Pakistan]             Australia
# 1              2             [Australia, Pakistan]             Australia
# 2              2             [Australia, Pakistan]             Australia
# 3              2             [Australia, Pakistan]             Australia
# 4              2             [Australia, Pakistan]             Australia
# ...          ...                               ...                   ...
# 694507      2426  [Scotland, United Arab Emirates]  United Arab Emirates
# 694508      2426  [Scotland, United Arab Emirates]  United Arab Emirates
# 694509      2426  [Scotland, United Arab Emirates]  United Arab Emirates
# 694510      2426  [Scotland, United Arab Emirates]  United Arab Emirates
# 694511      2426  [Scotland, United Arab Emirates]  United Arab Emirates
#
#         ball       batsman         bowler  runs player_dismissed       city  \
# 0        0.1     DA Warner  Mohammad Amir     0                0   Brisbane
# 1        0.2     DA Warner  Mohammad Amir     0                0   Brisbane
# 2        0.3     DA Warner  Mohammad Amir     0                0   Brisbane
# 3        0.4     DA Warner  Mohammad Amir     0                0   Brisbane
# 4        0.5     DA Warner  Mohammad Amir     1                0   Brisbane
# ...      ...           ...            ...   ...              ...        ...
# 694507  44.6    Ahmed Raza        CB Sole     0                0  Edinburgh
# 694508  45.1  Fayyaz Ahmed       AC Evans     1                0  Edinburgh
# 694509  45.2    Ahmed Raza       AC Evans     0                0  Edinburgh
# 694510  45.3    Ahmed Raza       AC Evans     0                0  Edinburgh
# 694511  45.4    Ahmed Raza       AC Evans     0       Ahmed Raza  Edinburgh
#
#                                             venue bowling_team
# 0          Brisbane Cricket Ground, Woolloongabba     Pakistan
# 1          Brisbane Cricket Ground, Woolloongabba     Pakistan
# 2          Brisbane Cricket Ground, Woolloongabba     Pakistan
# 3          Brisbane Cricket Ground, Woolloongabba     Pakistan
# 4          Brisbane Cricket Ground, Woolloongabba     Pakistan
# ...                                           ...          ...
# 694507  Grange Cricket Club Ground, Raeburn Place     Scotland
# 694508  Grange Cricket Club Ground, Raeburn Place     Scotland
# 694509  Grange Cricket Club Ground, Raeburn Place     Scotland
# 694510  Grange Cricket Club Ground, Raeburn Place     Scotland
# 694511  Grange Cricket Club Ground, Raeburn Place     Scotland
#
# [694512 rows x 11 columns]

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Australia', 'Pakistan', 'Scotland', 'Zimbabwe', 'New Zealand',
#        'Bangladesh', 'South Africa', 'India', 'England', 'Sri Lanka',
#        'Hong Kong', 'Papua New Guinea', 'West Indies', 'Ireland',
#        'United Arab Emirates', 'Nepal', 'United States of America',
#        'Namibia', 'Oman', 'Netherlands', 'Canada', 'Jersey', 'Africa XI',
#        'Kenya', 'Bermuda', 'Asia XI'], dtype=object)

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df.head()
# Out:
#    match_id batting_team  ball    batsman         bowler  runs  \
# 0         2    Australia   0.1  DA Warner  Mohammad Amir     0
# 1         2    Australia   0.2  DA Warner  Mohammad Amir     0
# 2         2    Australia   0.3  DA Warner  Mohammad Amir     0
# 3         2    Australia   0.4  DA Warner  Mohammad Amir     0
# 4         2    Australia   0.5  DA Warner  Mohammad Amir     1
#
#   player_dismissed      city                                   venue  \
# 0                0  Brisbane  Brisbane Cricket Ground, Woolloongabba
# 1                0  Brisbane  Brisbane Cricket Ground, Woolloongabba
# 2                0  Brisbane  Brisbane Cricket Ground, Woolloongabba
# 3                0  Brisbane  Brisbane Cricket Ground, Woolloongabba
# 4                0  Brisbane  Brisbane Cricket Ground, Woolloongabba
#
#   bowling_team
# 0     Pakistan
# 1     Pakistan
# 2     Pakistan
# 3     Pakistan
# 4     Pakistan

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
pickle.dump(output,open('dataset_level2.pkl','wb'))
