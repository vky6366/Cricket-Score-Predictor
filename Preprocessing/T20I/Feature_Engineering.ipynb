# %%
import numpy as np
import pandas as pd
import pickle

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  NaN
# 1         2    Australia    Sri Lanka   0.2     0                0  NaN
# 2         2    Australia    Sri Lanka   0.3     1                0  NaN
# 3         2    Australia    Sri Lanka   0.4     2                0  NaN
# 4         2    Australia    Sri Lanka   0.5     0                0  NaN
#
#                       venue
# 0  Melbourne Cricket Ground
# 1  Melbourne Cricket Ground
# 2  Melbourne Cricket Ground
# 3  Melbourne Cricket Ground
# 4  Melbourne Cricket Ground

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8549
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        3092
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sylhet International Cricket Stadium        128
# Sharjah Cricket Stadium                     127
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()
df = df[df['city'].isin(eligible_cities)]

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne

# %%
print(df.dtypes)
# Out:
# match_id              int64
# batting_team         object
# bowling_team         object
# ball                float64
# runs                  int64
# player_dismissed     object
# city                 object
# dtype: object

# %%
df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 312869      2601    Sri Lanka    Australia  19.3     1                0
# 312870      2601    Sri Lanka    Australia  19.4     0                0
# 312871      2601    Sri Lanka    Australia  19.5     0      DM de Silva
# 312872      2601    Sri Lanka    Australia  19.6     2                0
# 312873      2601    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score over ball_no
# 0       Melbourne              0    0       1
# 1       Melbourne              0    0       2
# 2       Melbourne              1    0       3
# 3       Melbourne              3    0       4
# 4       Melbourne              3    0       5
# ...           ...            ...  ...     ...
# 312869    Colombo            125   19       3
# 312870    Colombo            125   19       4
# 312871    Colombo            125   19       5
# 312872    Colombo            127   19       6
# 312873    Colombo            128   19       7
#
# [83520 rows x 10 columns]

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()
df['wickets_left'] = 10 - df['player_dismissed']
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 312869      2601    Sri Lanka    Australia  19.3     1                 8
# 312870      2601    Sri Lanka    Australia  19.4     0                 8
# 312871      2601    Sri Lanka    Australia  19.5     0                 9
# 312872      2601    Sri Lanka    Australia  19.6     2                 9
# 312873      2601    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# 0       Melbourne              0    0       1             1         119
# 1       Melbourne              0    0       2             2         118
# 2       Melbourne              1    0       3             3         117
# 3       Melbourne              3    0       4             4         116
# 4       Melbourne              3    0       5             5         115
# ...           ...            ...  ...     ...           ...         ...
# 312869    Colombo            125   19       3           117           3
# 312870    Colombo            125   19       4           118           2
# 312871    Colombo            125   19       5           119           1
# 312872    Colombo            127   19       6           120           0
# 312873    Colombo            128   19       7           121           0
#
#         wickets_left
# 0                 10
# 1                 10
# 2                 10
# 3                 10
# 4                 10
# ...              ...
# 312869             2
# 312870             2
# 312871             1
# 312872             1
# 312873             1
#
# [83520 rows x 13 columns]

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 312869      2601    Sri Lanka    Australia  19.3     1                 8
# 312870      2601    Sri Lanka    Australia  19.4     0                 8
# 312871      2601    Sri Lanka    Australia  19.5     0                 9
# 312872      2601    Sri Lanka    Australia  19.6     2                 9
# 312873      2601    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# 0       Melbourne              0    0       1             1         119
# 1       Melbourne              0    0       2             2         118
# 2       Melbourne              1    0       3             3         117
# 3       Melbourne              3    0       4             4         116
# 4       Melbourne              3    0       5             5         115
# ...           ...            ...  ...     ...           ...         ...
# 312869    Colombo            125   19       3           117           3
# 312870    Colombo            125   19       4           118           2
# 312871    Colombo            125   19       5           119           1
# 312872    Colombo            127   19       6           120           0
# 312873    Colombo            128   19       7           121           0
#
#         wickets_left       crr
# 0                 10  0.000000
# 1                 10  0.000000
# 2                 10  2.000000
# 3                 10  4.500000
# 4                 10  3.600000
# ...              ...       ...
# 312869             2  6.410256
# 312870             2  6.355932
# 312871             1  6.302521
# 312872             1  6.350000
# 312873             1  6.347107
#
# [83520 rows x 14 columns]

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []

for id in match_ids:
    runs_rolling = groups.get_group(id)['runs'].rolling(window=30).sum()
    last_five.extend(runs_rolling.values.tolist())

df['last_five'] = last_five

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])
final_df.sample(2)
# Out:
#       batting_team bowling_team        city  current_score  balls_left  \
# 53562  New Zealand     Pakistan      London             69          49
# 14741     Pakistan      England  Manchester             82          63
#
#        wickets_left       crr  last_five  runs_x
# 53562             6  5.830986       29.0      99
# 14741             8  8.631579       49.0     190

# %%
print(final_df.dtypes)
# Out:
# batting_team      object
# bowling_team      object
# city              object
# current_score      int64
# balls_left         int64
# wickets_left       int64
# crr              float64
# last_five        float64
# runs_x             int64
# dtype: object

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.head()
# Out:
#        batting_team bowling_team          city  current_score  balls_left  \
# 63152   West Indies      England        London             65          61
# 48488    Bangladesh    Australia     Cape Town            110          18
# 56731      Pakistan      England      Barbados             61          71
# 68934     Australia     Pakistan         Dubai             47          79
# 74708  South Africa     Pakistan  Johannesburg            116          21
#
#        wickets_left       crr  last_five  runs_x
# 63152             8  6.610169       22.0     125
# 48488             4  6.470588       36.0     123
# 56731             9  7.469388       33.0     147
# 68934            10  6.878049       38.0     168
# 74708             5  7.030303       28.0     153

# %%
pickle.dump(final_df,open('dataset_final.pkl','wb'))
